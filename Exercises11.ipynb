# %% [markdown]
# # Week 11 - Exercises and Homework

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Human body statistics
#
# The file `"heights_weights_genders.csv"` contains the height and weight data of 5000 men and 5000 women.
#
# Let's load the data:

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mkozturk/AI111/refs/heads/main/heights_weights_genders.csv")
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# Using matplotlib, generate the following histograms of height data pertaining to men and women.
#
# Histograms use 40 bins and have an alpha (opacity) level of 0.75.

# %%
# your code here

# %% [markdown]
# Using matplotlib, generate the following scatter plot from the data:

# %%
# your code here

# %% [markdown]
# # 2. The Titanic
#
# Let's load the *Titanic* dataset again.

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/mkozturk/AI111/refs/heads/main/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Do the following tasks using `groupby()` aggregations and `print()` statements.

# %% [markdown]
# (a) Get the count of all passengers from either sex:

# %%
# your code here
# Out:
# There were 314 women and 577 men on the Titanic

# %% [markdown]
# (b) Get the count of all surviving passengers ("Survived" is 1), grouped by sex.

# %%
# your code here
# Out:
# Only 233 women and 109 men survived

# %% [markdown]
# (c) Get the mean age of groups broken by survival and sex:

# %%
# your code here
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %% [markdown]
# (d) There are three passenger classes (`Pclass`), 1 being the most expensive, 3 being the cheapest. Display the count of each class in the ship.

# %%
# your code here
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Name, dtype: int64

# %% [markdown]
# (e) Break the previous result by the survival column to see how many people from each passenger class have survived.

# %%
# your code here
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Name, dtype: int64

# %% [markdown]
# (f) (Optional) Inspired by this result, write a 1000-word essay about the irony of rich people telling the poor "we are on the same boat".

# %% [markdown]
# # 3. Country comparisons
#
# All data in this part, and more, can be found at https://www.cia.gov/the-world-factbook/references/guide-to-country-comparisons/

# %% [markdown]
# ## (a) Plot the country areas
# The file `country_area.csv` contains the size of every country in the world.
#
# Let's load the data:

# %%
area = pd.read_csv("https://raw.githubusercontent.com/mkozturk/AI111/refs/heads/main/country_area.csv", thousands=",")
area.head()
# Out:
#             name           slug     sq km  date_of_information  ranking  \
# 0         Russia         russia  17098242                  NaN        1
# 1     Antarctica     antarctica  14200000                  NaN        2
# 2         Canada         canada   9984670                  NaN        3
# 3  United States  united-states   9833517                  NaN        4
# 4          China          china   9596960                  NaN        5
#
#                     region
# 0             Central Asia
# 1               Antarctica
# 2            North America
# 3            North America
# 4  East and Southeast Asia

# %% [markdown]
# Look up the documentation of `read_csv()` to understand what the parameter `thousands=","` is doing.
#
# Using this data frame, generate a *horizontal bar plot* of the areas of the largest 20 countries, ordered by size, exactly as below.
#
# You may need the `DataFrame.sort_values()` method. Look it up from the pandas documentation.
#
# **Notice:** The third column's label starts with an invisible space. It is " sq km", not "sq km".

# %%
# your code here

# %% [markdown]
# ## (b) Plot the population density
#
# The file `country_population.csv` contains the population of every country.
#
# Load this file into a dataframe. Check that it is correctly loaded with `.head()`.

# %%
pop = pd.read_csv("https://raw.githubusercontent.com/mkozturk/AI111/refs/heads/main/country_population.csv", thousands=",")

# %% [markdown]
# Merge it with the `area` dataframe on the `slug` column. Name the resulting data frame `countries`.
#
# Examine the resulting data frame. You will see some repeated columns. Remove unnecessary columns, rename the rest, so that you end up with the following data frame.

# %%
# your code here

# %%
countries.head()
# Out:
#             name           slug      area                   region  population
# 0         Russia         russia  17098242             Central Asia   140820810
# 1         Canada         canada   9984670            North America    38794813
# 2  United States  united-states   9833517            North America   341963408
# 3          China          china   9596960  East and Southeast Asia  1416043270
# 4         Brazil         brazil   8515770            South America   220051512

# %% [markdown]
# If the columns are the same but appear in a different order, don't worry.

# %% [markdown]
# Add a new column named `density`, which is the population density (population divided by the area, that is, people per square kilometers).

# %%
# your code here

# %%
countries.head()
# Out:
#             name           slug      area                   region  \
# 0         Russia         russia  17098242             Central Asia
# 1         Canada         canada   9984670            North America
# 2  United States  united-states   9833517            North America
# 3          China          china   9596960  East and Southeast Asia
# 4         Brazil         brazil   8515770            South America
#
#    population     density
# 0   140820810    8.235982
# 1    38794813    3.885438
# 2   341963408   34.775290
# 3  1416043270  147.551232
# 4   220051512   25.840472

# %% [markdown]
# Using this data frame, generate a horizontal bar plot showing 20 countries with the *highest* population density, in decreasing order, exactly as below.
#
# Also generate a similar plot showing 20 countries with the *lowest* population density.
#
# If you see some "weirdness" in your plot, look at the data to explain it.

# %%
# your code here
# Out:
# /home/kaan/lectures/.venv/lib/python3.13/site-packages/matplotlib/transforms.py:2437: RuntimeWarning: invalid value encountered in dot
#   return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# /home/kaan/lectures/.venv/lib/python3.13/site-packages/matplotlib/transforms.py:2437: RuntimeWarning: invalid value encountered in dot
#   return Affine2D(np.dot(self._b.get_affine().get_matrix(),

# %% [markdown]
# Countries with very dense populations are usually very small, many of them tiny islands with a few thousands of people.
#
# Again, generate a horizontal bar plot showing 20 countries with the highest population density, this time selecting only countries *larger* than 1000 square kms.

# %%
# your code here

# %% [markdown]
# ## (c) Analyzing regions
#
# Group the `countries` data by the `region` column to get the total population and area of each region.
#
# Set the resulting data frame to a new variable `regions`.

# %%
# your code here

# %%
regions
# Out:
#                                        area  population
# region
# Africa                             30316641  1485428913
# Australia and Oceania               8100051    35485935
# Central America and the Caribbean    755692    94021465
# Central Asia                       21288736   238439689
# East and Southeast Asia            16753730  2363149283
# Europe                              6065774   602584227
# Middle East                         6286332   359657872
# North America                      23948944   511633831
# South America                      17744519   442163296
# South Asia                          5135531  1924689002

# %% [markdown]
# Create a bar plot of *population density* aggregated over regions, ordered by density.

# %%
# your code here

# %% [markdown]
# ## (d) Some socioeconomic indicators
#
# The file `"country_GDP_PPP.csv"` holds the gross domestic product (purchasing power parity) of countries, in US dollars.
#
# The file `"country_life_exp.csv"` holds the life expectation at birth for every country, in years.
#
# The file `"country_CO2.csv"` holds the annual CO2 emission for each country, in metric tonnes.
#
# Load these files into data frames. Examine the data frames to check if they make sense.

# %%
gdp = pd.read_csv("https://raw.githubusercontent.com/mkozturk/AI111/refs/heads/main/country_GDP_PPP.csv")
gdp["value"] = gdp["value"].replace({r"\$":"", ",": ""}, regex=True).astype(int) # can you infer what this line does?

lifeexp = pd.read_csv("https://raw.githubusercontent.com/mkozturk/AI111/refs/heads/main/country_life_exp.csv")
co2 = pd.read_csv("https://raw.githubusercontent.com/mkozturk/AI111/refs/heads/main/country_CO2.csv",thousands=",")

# %% [markdown]
# Merge these new data frames with your existing `countries` data frame to generate the following data frame.
#
# You will need to perform three `merge()` operations, followed by some column removal and renaming, as you've done before.

# %%
# your code here

# %%
countries.head()
# Out:
#             name           slug      area  population             GDP  \
# 0         Russia         russia  17098242   140820810   6089000000000
# 1         Canada         canada   9984670    38794813   2341000000000
# 2  United States  united-states   9833517   341963408  25676000000000
# 3          China          china   9596960  1416043270  33598000000000
# 4         Brazil         brazil   8515770   220051512   4165000000000
#
#    life exp          CO2                   region
# 0      72.3   1844000000             Central Asia
# 1      84.2    585853000            North America
# 2      80.9   4795000000            North America
# 3      78.7  12196000000  East and Southeast Asia
# 4      76.3    437769000            South America

# %% [markdown]
# Create a scatter plot of CO2 emissions against the GDP.

# %%
# your code here

# %% [markdown]
# There is a heavy skewness in the data. A common trick is to use *logarithmic axes* on the plot. Logarithmic axes amplify small values and shrink large values.
#
# Look up the documentation of `DataFrame.plot()` method and figure out how to convert both axes to logarithmic, as show below:

# %%
# your code here

# %% [markdown]
# Now, color the points according to the life expectancy values, as shown below:

# %%
# your code here
