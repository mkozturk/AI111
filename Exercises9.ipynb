# %% [markdown]
# # Exercises and Homework 9 - Numpy and Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Array creation
# Generate the following arrays with NumPy
#
# (a) Between 1 and 10 with steps of 1.25
#
# (b) Between 10 and 1 backwards, with steps of 1.25
#
# (c) Between 1 and 10, including both values, with exactly 19 elements.
#
# (d) Between 10 and 1 backwards, including both values, with exactly 19 elements.
#
# (e) Ten random numbers between 0 and 1, uniformly distributed.
#
# (f) Ten random numbers, normally distributed with mean zero and standard deviation of one.
#
# (g) An array of 20 elements, all elements equal to 2.

# %% [markdown]
# ## 2. Data Analysis

# %% [markdown]
# The file `data_ex9_2.csv` stores grades for a set of students on four different subjects, one row per student.
#
# * First column: The name of the student.
# * Second column: The gender of the student. 1 for women, 2 for men.
# * Third column: The group number of the student.
# * Fourth to seventh columns: Grades from subjects math, physics, literature, and music, respectively.
#
# Load the data into a NumPy array using the `loadtxt()` function. Set up parameters so that you exclude non-numerical columns.

# %% [markdown]
# (a) Calculate the averages of subjects over the entire student body using *numpy* functions , and print the following output (use string formatting).
#
# ```
# Average score for math       is 49.6
# Average score for physics    is 60.6
# Average score for literature is 45.4
# Average score for music      is 57.3
# ```

# %% [markdown]
# (b) Calculate the average of every subject separately for men and women. Display your results as shown below.
#
# Hint: Use Boolean indexing over the second axis of `grades` to select the rows where the first column value is 1 (for women) or 2 (for men)
#
# ```
# Average scores for women, broken by subject
# math       : 49.0
# physics    : 59.5
# literature : 44.4
# music      : 58.6
# Average scores for men, broken by subject
# math       : 50.2
# physics    : 61.8
# literature : 46.4
# music      : 56.0
# ```

# %% [markdown]
# (c) Calculate **the mean** and **the standard deviation** of the scores in each subject, **broken by group numbers**. Display your results as shown below.
#
# ```
# Average and standard deviation of groups, broken by subject
# Group 1
# 	math       : 49.1 +/- 10.1
# 	physics    : 55.9 +/- 11.6
# 	literature : 46.2 +/- 11.2
# 	music      : 64.7 +/- 16.2
# Group 2
# 	math       : 49.1 +/- 12.9
# 	physics    : 60.2 +/- 15.1
# 	literature : 48.3 +/- 10.6
# 	music      : 52.7 +/- 18.7
# Group 3
# 	math       : 49.6 +/- 8.9
# 	physics    : 62.3 +/- 14.1
# 	literature : 40.2 +/- 10.4
# 	music      : 60.3 +/- 13.2
# Group 4
# 	math       : 50.3 +/- 10.3
# 	physics    : 62.7 +/- 16.7
# 	literature : 46.3 +/- 13.4
# 	music      : 54.4 +/- 17.2
# ```

# %% [markdown]
# ## 3. Function plotting
# (a) Using matplotlib, plot the sine and cosine functions over the interval $(-2\pi, 2\pi)$.
#
# First generate an array spanning the interval. The constant $\pi$ is available as `np.pi`. Use the `np.sin()` and `np.cos()` functions to calculate the values.
#
# Your plot should look like below:

# %% [markdown]
# (b) The cosine function can be approximated near $x=0$ with
#
# * $1-\frac{x^2}{2}$
# * $1-\frac{x^2}{2}+\frac{x^4}{24}$
# * $1-\frac{x^2}{2}+\frac{x^4}{24}-\frac{x^6}{720}$
#
# each providing a better approximation. The graph below illustrates this sequence of approximations.
#
# Recreate this plot *exactly* using matplotlib.

# %% [markdown]
# ## 4. Data plotting

# %% [markdown]
# The file *EuStockMarkets.csv* contains daily closing prices of major european stock indices between 1991 and 1998.
#
# Load the file using `loadtxt()` and create the following plot exactly.

# %% [markdown]
# ## 5. Random Walk Simulation

# %% [markdown]
# A *random walk* consists of steps taken randomly in either direction. We can simulate a random walk by generating a sequence of random steps, and add them up.

# %% [markdown]
# (a) Generate a 30-step random walk: Create an array of 30 normally distributed random numbers with `randn()`. Add them at each step with `cumsum()`. Plot the result.

# %%
np.random.seed(111)

# %% [markdown]
# (b) Generate 1000 random walks, each of length 50, and plot them on the same graph as shown below.
#
# Adjust the line width and transparency values so that lines do not obscure each other.
#
# Hint: Use a single `randn()` function call to generate a 50-by-1000 array of random numbers and `cumsum` them over the appropriate axis.

# %%
np.random.seed(111)

# %% [markdown]
# (c) Calculate the mean of the random walk at every step and overlay it on the graph of individual walks, as shown below.
